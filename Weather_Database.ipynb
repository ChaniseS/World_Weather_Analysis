# %%
# Import dependencies

from citipy import citipy
import pandas as pd
import numpy as np
import json 
import requests
import timeit

from datetime import datetime
from config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes.

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Get the nearest city using the citipy module.

from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 744

# %%
# Perform an API call with the OpenWeatherMap.

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fdf62d6d2c1da7c8e3eef9bebb15a147

# %%
# Retrieve the following information from the API call:
# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)


# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | auki
# Processing Record 2 of Set 1 | havelock
# Processing Record 3 of Set 1 | puerto ayora
# Processing Record 4 of Set 1 | port hardy
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | chokurdakh
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | yulara
# Processing Record 10 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 1 | balgazyn
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | valparaiso
# Processing Record 14 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 1 | saint-philippe
# Processing Record 16 of Set 1 | bambous virieux
# Processing Record 17 of Set 1 | vao
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | dikson
# Processing Record 20 of Set 1 | hithadhoo
# Processing Record 21 of Set 1 | kalaleh
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 1 | nikolskoye
# Processing Record 25 of Set 1 | beringovskiy
# Processing Record 26 of Set 1 | labuhan
# Processing Record 27 of Set 1 | plaster rock
# Processing Record 28 of Set 1 | arraial do cabo
# Processing Record 29 of Set 1 | carnarvon
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | barrow
# Processing Record 32 of Set 1 | tupik
# Processing Record 33 of Set 1 | saint george
# Processing Record 34 of Set 1 | kaitangata
# Processing Record 35 of Set 1 | iqaluit
# Processing Record 36 of Set 1 | castro
# Processing Record 37 of Set 1 | tasiilaq
# Processing Record 38 of Set 1 | pevek
# Processing Record 39 of Set 1 | jamestown
# Processing Record 40 of Set 1 | noumea
# Processing Record 41 of Set 1 | erice
# Processing Record 42 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 1 | alofi
# Processing Record 44 of Set 1 | surt
# Processing Record 45 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 1 | along
# Processing Record 47 of Set 1 | rzhev
# Processing Record 48 of Set 1 | atuona
# Processing Record 49 of Set 1 | klaksvik
# Processing Record 50 of Set 1 | mareeba
# Processing Record 1 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 2 | ponta do sol
# Processing Record 3 of Set 2 | piryion
# City not found. Skipping...
# Processing Record 4 of Set 2 | caravelas
# Processing Record 5 of Set 2 | hilo
# Processing Record 6 of Set 2 | busselton
# Processing Record 7 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 2 | mackenzie
# Processing Record 9 of Set 2 | mutsamudu
# City not found. Skipping...
# Processing Record 10 of Set 2 | ystad
# Processing Record 11 of Set 2 | buala
# Processing Record 12 of Set 2 | oriximina
# Processing Record 13 of Set 2 | malanje
# Processing Record 14 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 2 | anadyr
# Processing Record 16 of Set 2 | commerce
# Processing Record 17 of Set 2 | dongli
# Processing Record 18 of Set 2 | lompoc
# Processing Record 19 of Set 2 | tuktoyaktuk
# Processing Record 20 of Set 2 | gulshat
# City not found. Skipping...
# Processing Record 21 of Set 2 | san quintin
# Processing Record 22 of Set 2 | port alfred
# Processing Record 23 of Set 2 | namibe
# Processing Record 24 of Set 2 | athabasca
# Processing Record 25 of Set 2 | albany
# Processing Record 26 of Set 2 | esperance
# Processing Record 27 of Set 2 | vardo
# Processing Record 28 of Set 2 | pimenta bueno
# Processing Record 29 of Set 2 | mashhad
# Processing Record 30 of Set 2 | kodiak
# Processing Record 31 of Set 2 | batesville
# Processing Record 32 of Set 2 | el faiyum
# City not found. Skipping...
# Processing Record 33 of Set 2 | avarua
# Processing Record 34 of Set 2 | adrar
# Processing Record 35 of Set 2 | mackay
# Processing Record 36 of Set 2 | aktau
# Processing Record 37 of Set 2 | constantine
# Processing Record 38 of Set 2 | geraldton
# Processing Record 39 of Set 2 | kahului
# Processing Record 40 of Set 2 | victoria
# Processing Record 41 of Set 2 | bredasdorp
# Processing Record 42 of Set 2 | baykit
# Processing Record 43 of Set 2 | uhlove
# Processing Record 44 of Set 2 | aguimes
# Processing Record 45 of Set 2 | itarema
# Processing Record 46 of Set 2 | butaritari
# Processing Record 47 of Set 2 | komsomolskiy
# Processing Record 48 of Set 2 | poum
# Processing Record 49 of Set 2 | sambava
# Processing Record 50 of Set 2 | viesca
# Processing Record 1 of Set 3 | saldanha
# Processing Record 2 of Set 3 | kavieng
# Processing Record 3 of Set 3 | clyde river
# Processing Record 4 of Set 3 | upernavik
# Processing Record 5 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 6 of Set 3 | kurush
# Processing Record 7 of Set 3 | sivas
# Processing Record 8 of Set 3 | yellowknife
# Processing Record 9 of Set 3 | tilichiki
# Processing Record 10 of Set 3 | kavaratti
# Processing Record 11 of Set 3 | inhambane
# Processing Record 12 of Set 3 | qaanaaq
# Processing Record 13 of Set 3 | hobart
# Processing Record 14 of Set 3 | kargasok
# Processing Record 15 of Set 3 | pacific grove
# Processing Record 16 of Set 3 | yialos
# City not found. Skipping...
# Processing Record 17 of Set 3 | coihaique
# Processing Record 18 of Set 3 | bubaque
# Processing Record 19 of Set 3 | champerico
# Processing Record 20 of Set 3 | whitehorse
# Processing Record 21 of Set 3 | marzuq
# Processing Record 22 of Set 3 | mar del plata
# Processing Record 23 of Set 3 | korla
# Processing Record 24 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 3 | lima
# Processing Record 26 of Set 3 | ostrovnoy
# Processing Record 27 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 3 | texarkana
# Processing Record 29 of Set 3 | sembakung
# Processing Record 30 of Set 3 | roald
# Processing Record 31 of Set 3 | ternate
# Processing Record 32 of Set 3 | kathu
# Processing Record 33 of Set 3 | beira
# Processing Record 34 of Set 3 | nouadhibou
# Processing Record 35 of Set 3 | cirpan
# City not found. Skipping...
# Processing Record 36 of Set 3 | oshikango
# Processing Record 37 of Set 3 | east london
# Processing Record 38 of Set 3 | dalnegorsk
# Processing Record 39 of Set 3 | bathsheba
# Processing Record 40 of Set 3 | tiksi
# Processing Record 41 of Set 3 | martapura
# Processing Record 42 of Set 3 | saskylakh
# Processing Record 43 of Set 3 | changji
# Processing Record 44 of Set 3 | egvekinot
# Processing Record 45 of Set 3 | te anau
# Processing Record 46 of Set 3 | palmer
# Processing Record 47 of Set 3 | saint andrews
# Processing Record 48 of Set 3 | lac du bonnet
# Processing Record 49 of Set 3 | matagami
# Processing Record 50 of Set 3 | narsaq
# Processing Record 1 of Set 4 | shetpe
# Processing Record 2 of Set 4 | trincomalee
# Processing Record 3 of Set 4 | hun
# Processing Record 4 of Set 4 | ouallam
# Processing Record 5 of Set 4 | khani
# Processing Record 6 of Set 4 | vestnes
# Processing Record 7 of Set 4 | coquimbo
# Processing Record 8 of Set 4 | lagoa
# Processing Record 9 of Set 4 | quatre cocos
# Processing Record 10 of Set 4 | nanakuli
# Processing Record 11 of Set 4 | souillac
# Processing Record 12 of Set 4 | yelizovo
# Processing Record 13 of Set 4 | williston
# Processing Record 14 of Set 4 | santa marta
# Processing Record 15 of Set 4 | norman wells
# Processing Record 16 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 4 | cherskiy
# Processing Record 18 of Set 4 | new norfolk
# Processing Record 19 of Set 4 | cape town
# Processing Record 20 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 4 | ostrov
# Processing Record 22 of Set 4 | kawana waters
# City not found. Skipping...
# Processing Record 23 of Set 4 | longyearbyen
# Processing Record 24 of Set 4 | provideniya
# Processing Record 25 of Set 4 | hagi
# Processing Record 26 of Set 4 | nanortalik
# Processing Record 27 of Set 4 | namatanai
# Processing Record 28 of Set 4 | gurlan
# Processing Record 29 of Set 4 | itaparica
# Processing Record 30 of Set 4 | touros
# Processing Record 31 of Set 4 | qui nhon
# Processing Record 32 of Set 4 | severo-kurilsk
# Processing Record 33 of Set 4 | beroroha
# Processing Record 34 of Set 4 | hofn
# Processing Record 35 of Set 4 | talnakh
# Processing Record 36 of Set 4 | san patricio
# Processing Record 37 of Set 4 | olafsvik
# Processing Record 38 of Set 4 | ancud
# Processing Record 39 of Set 4 | mogadishu
# Processing Record 40 of Set 4 | los llanos de aridane
# Processing Record 41 of Set 4 | fevralsk
# City not found. Skipping...
# Processing Record 42 of Set 4 | hasaki
# Processing Record 43 of Set 4 | goderich
# Processing Record 44 of Set 4 | husavik
# Processing Record 45 of Set 4 | stepnyak
# Processing Record 46 of Set 4 | mehran
# Processing Record 47 of Set 4 | ilulissat
# Processing Record 48 of Set 4 | san cristobal
# Processing Record 49 of Set 4 | juba
# Processing Record 50 of Set 4 | hue
# Processing Record 1 of Set 5 | port moresby
# Processing Record 2 of Set 5 | dwarka
# Processing Record 3 of Set 5 | grindavik
# Processing Record 4 of Set 5 | khatanga
# Processing Record 5 of Set 5 | piacabucu
# Processing Record 6 of Set 5 | kenora
# Processing Record 7 of Set 5 | port hawkesbury
# Processing Record 8 of Set 5 | hermanus
# Processing Record 9 of Set 5 | tawang
# Processing Record 10 of Set 5 | hongjiang
# Processing Record 11 of Set 5 | lebu
# Processing Record 12 of Set 5 | saryshagan
# City not found. Skipping...
# Processing Record 13 of Set 5 | sterling
# Processing Record 14 of Set 5 | faanui
# Processing Record 15 of Set 5 | cidreira
# Processing Record 16 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 5 | ribeira grande
# Processing Record 18 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 5 | requena
# Processing Record 20 of Set 5 | macaboboni
# City not found. Skipping...
# Processing Record 21 of Set 5 | puerto maldonado
# Processing Record 22 of Set 5 | waingapu
# Processing Record 23 of Set 5 | urumqi
# Processing Record 24 of Set 5 | bull savanna
# Processing Record 25 of Set 5 | anshun
# Processing Record 26 of Set 5 | vincennes
# Processing Record 27 of Set 5 | krasnyy chikoy
# Processing Record 28 of Set 5 | shimoda
# Processing Record 29 of Set 5 | murdochville
# Processing Record 30 of Set 5 | salalah
# Processing Record 31 of Set 5 | merchtem
# Processing Record 32 of Set 5 | tuatapere
# Processing Record 33 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 5 | juegang
# Processing Record 35 of Set 5 | diapaga
# Processing Record 36 of Set 5 | greiz
# Processing Record 37 of Set 5 | helong
# Processing Record 38 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 39 of Set 5 | tabory
# Processing Record 40 of Set 5 | manokwari
# Processing Record 41 of Set 5 | airai
# Processing Record 42 of Set 5 | lavrentiya
# Processing Record 43 of Set 5 | shenjiamen
# Processing Record 44 of Set 5 | bobonong
# City not found. Skipping...
# Processing Record 45 of Set 5 | maxixe
# Processing Record 46 of Set 5 | coahuayana
# Processing Record 47 of Set 5 | sao domingos
# Processing Record 48 of Set 5 | okakarara
# Processing Record 49 of Set 5 | palkonda
# Processing Record 50 of Set 5 | phalombe
# Processing Record 1 of Set 6 | nome
# Processing Record 2 of Set 6 | mosalsk
# Processing Record 3 of Set 6 | gorlice
# Processing Record 4 of Set 6 | saint-francois
# Processing Record 5 of Set 6 | kiknur
# Processing Record 6 of Set 6 | broome
# Processing Record 7 of Set 6 | sao joao da barra
# Processing Record 8 of Set 6 | salinopolis
# Processing Record 9 of Set 6 | okhotsk
# Processing Record 10 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 11 of Set 6 | shalinskoye
# Processing Record 12 of Set 6 | tanete
# Processing Record 13 of Set 6 | maniitsoq
# Processing Record 14 of Set 6 | neryungri
# Processing Record 15 of Set 6 | panaba
# Processing Record 16 of Set 6 | mount isa
# Processing Record 17 of Set 6 | makokou
# Processing Record 18 of Set 6 | kruisfontein
# Processing Record 19 of Set 6 | plerin
# Processing Record 20 of Set 6 | sigli
# Processing Record 21 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 6 | svetlyy
# Processing Record 23 of Set 6 | half moon bay
# Processing Record 24 of Set 6 | bethel
# Processing Record 25 of Set 6 | todos santos
# Processing Record 26 of Set 6 | port elizabeth
# Processing Record 27 of Set 6 | igrim
# Processing Record 28 of Set 6 | sur
# Processing Record 29 of Set 6 | mwinilunga
# Processing Record 30 of Set 6 | luderitz
# Processing Record 31 of Set 6 | viedma
# Processing Record 32 of Set 6 | tual
# Processing Record 33 of Set 6 | avera
# Processing Record 34 of Set 6 | north bend
# Processing Record 35 of Set 6 | jose bonifacio
# Processing Record 36 of Set 6 | laramie
# Processing Record 37 of Set 6 | kamenka
# Processing Record 38 of Set 6 | la maddalena
# Processing Record 39 of Set 6 | marana
# Processing Record 40 of Set 6 | krasnoselkup
# Processing Record 41 of Set 6 | mancio lima
# Processing Record 42 of Set 6 | mahebourg
# Processing Record 43 of Set 6 | karratha
# Processing Record 44 of Set 6 | taoudenni
# Processing Record 45 of Set 6 | chuy
# Processing Record 46 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 6 | walvis bay
# Processing Record 48 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 49 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 50 of Set 6 | nizhniy kuranakh
# Processing Record 1 of Set 7 | rivera
# Processing Record 2 of Set 7 | kumano
# Processing Record 3 of Set 7 | weyburn
# Processing Record 4 of Set 7 | sakakah
# Processing Record 5 of Set 7 | barra do garcas
# Processing Record 6 of Set 7 | san policarpo
# Processing Record 7 of Set 7 | deputatskiy
# Processing Record 8 of Set 7 | shitkino
# Processing Record 9 of Set 7 | ardon
# Processing Record 10 of Set 7 | katsuura
# Processing Record 11 of Set 7 | la paz
# Processing Record 12 of Set 7 | lorengau
# Processing Record 13 of Set 7 | visby
# Processing Record 14 of Set 7 | praia da vitoria
# Processing Record 15 of Set 7 | hobyo
# Processing Record 16 of Set 7 | kununurra
# Processing Record 17 of Set 7 | mamallapuram
# Processing Record 18 of Set 7 | cabo san lucas
# Processing Record 19 of Set 7 | san vicente
# Processing Record 20 of Set 7 | cururupu
# Processing Record 21 of Set 7 | glendive
# Processing Record 22 of Set 7 | bokspits
# City not found. Skipping...
# Processing Record 23 of Set 7 | atherton
# Processing Record 24 of Set 7 | halifax
# Processing Record 25 of Set 7 | umm lajj
# Processing Record 26 of Set 7 | marsh harbour
# Processing Record 27 of Set 7 | sitka
# Processing Record 28 of Set 7 | churapcha
# Processing Record 29 of Set 7 | kazachinskoye
# Processing Record 30 of Set 7 | griffith
# Processing Record 31 of Set 7 | novyy urgal
# Processing Record 32 of Set 7 | mao
# Processing Record 33 of Set 7 | haines junction
# Processing Record 34 of Set 7 | novikovo
# Processing Record 35 of Set 7 | tubruq
# City not found. Skipping...
# Processing Record 36 of Set 7 | betare oya
# Processing Record 37 of Set 7 | mayskiy
# Processing Record 38 of Set 7 | polunochnoye
# Processing Record 39 of Set 7 | candolim
# Processing Record 40 of Set 7 | lively
# Processing Record 41 of Set 7 | kholodnyy
# Processing Record 42 of Set 7 | phu khieo
# City not found. Skipping...
# Processing Record 43 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 44 of Set 7 | aksu
# Processing Record 45 of Set 7 | hambantota
# Processing Record 46 of Set 7 | malatya
# Processing Record 47 of Set 7 | fairbanks
# Processing Record 48 of Set 7 | milas
# Processing Record 49 of Set 7 | beian
# Processing Record 50 of Set 7 | muros
# Processing Record 1 of Set 8 | kieta
# Processing Record 2 of Set 8 | tooele
# Processing Record 3 of Set 8 | tshikapa
# Processing Record 4 of Set 8 | torbay
# Processing Record 5 of Set 8 | jieshi
# Processing Record 6 of Set 8 | santa fe
# Processing Record 7 of Set 8 | belaya gora
# Processing Record 8 of Set 8 | asilah
# Processing Record 9 of Set 8 | portland
# Processing Record 10 of Set 8 | katangli
# Processing Record 11 of Set 8 | araouane
# Processing Record 12 of Set 8 | shagonar
# Processing Record 13 of Set 8 | bilma
# Processing Record 14 of Set 8 | vitim
# Processing Record 15 of Set 8 | hualmay
# Processing Record 16 of Set 8 | constitucion
# Processing Record 17 of Set 8 | ahipara
# Processing Record 18 of Set 8 | port macquarie
# Processing Record 19 of Set 8 | shingu
# Processing Record 20 of Set 8 | tabou
# Processing Record 21 of Set 8 | mogadouro
# Processing Record 22 of Set 8 | huambo
# Processing Record 23 of Set 8 | tonstad
# Processing Record 24 of Set 8 | puerto el triunfo
# Processing Record 25 of Set 8 | qandahar
# City not found. Skipping...
# Processing Record 26 of Set 8 | georgetown
# Processing Record 27 of Set 8 | zyryanka
# Processing Record 28 of Set 8 | merke
# Processing Record 29 of Set 8 | ziyang
# Processing Record 30 of Set 8 | port-cartier
# Processing Record 31 of Set 8 | marathon
# Processing Record 32 of Set 8 | yumen
# Processing Record 33 of Set 8 | byron bay
# Processing Record 34 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 35 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 36 of Set 8 | santa maria
# Processing Record 37 of Set 8 | eyl
# Processing Record 38 of Set 8 | yerbogachen
# Processing Record 39 of Set 8 | koprivstica
# Processing Record 40 of Set 8 | lucea
# Processing Record 41 of Set 8 | kurumkan
# Processing Record 42 of Set 8 | maragogi
# Processing Record 43 of Set 8 | emporia
# Processing Record 44 of Set 8 | bairiki
# Processing Record 45 of Set 8 | riyadh
# Processing Record 46 of Set 8 | miquelon
# Processing Record 47 of Set 8 | bolobo
# Processing Record 48 of Set 8 | scarborough
# Processing Record 49 of Set 8 | thompson
# Processing Record 50 of Set 8 | xining
# Processing Record 1 of Set 9 | la ronge
# Processing Record 2 of Set 9 | gazli
# Processing Record 3 of Set 9 | jinchang
# Processing Record 4 of Set 9 | san luis
# Processing Record 5 of Set 9 | cockburn town
# Processing Record 6 of Set 9 | wellington
# Processing Record 7 of Set 9 | coari
# Processing Record 8 of Set 9 | srivardhan
# Processing Record 9 of Set 9 | santa helena de goias
# Processing Record 10 of Set 9 | seoul
# Processing Record 11 of Set 9 | les cayes
# Processing Record 12 of Set 9 | disna
# Processing Record 13 of Set 9 | socorro
# Processing Record 14 of Set 9 | sabha
# Processing Record 15 of Set 9 | ojinaga
# Processing Record 16 of Set 9 | baherden
# Processing Record 17 of Set 9 | pangnirtung
# Processing Record 18 of Set 9 | berea
# Processing Record 19 of Set 9 | pochutla
# Processing Record 20 of Set 9 | gorin
# Processing Record 21 of Set 9 | amapa
# Processing Record 22 of Set 9 | misratah
# Processing Record 23 of Set 9 | srandakan
# Processing Record 24 of Set 9 | wainwright
# Processing Record 25 of Set 9 | gao
# Processing Record 26 of Set 9 | kalynivka
# Processing Record 27 of Set 9 | sunbury
# Processing Record 28 of Set 9 | itaituba
# Processing Record 29 of Set 9 | sibiti
# Processing Record 30 of Set 9 | cascais
# Processing Record 31 of Set 9 | umm durman
# City not found. Skipping...
# Processing Record 32 of Set 9 | leningradskiy
# Processing Record 33 of Set 9 | bitam
# Processing Record 34 of Set 9 | puerto madero
# Processing Record 35 of Set 9 | leshukonskoye
# Processing Record 36 of Set 9 | pravia
# Processing Record 37 of Set 9 | iroquois falls
# Processing Record 38 of Set 9 | litoral del san juan
# City not found. Skipping...
# Processing Record 39 of Set 9 | lichtenburg
# Processing Record 40 of Set 9 | rantepao
# Processing Record 41 of Set 9 | kaeo
# Processing Record 42 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 43 of Set 9 | revelstoke
# Processing Record 44 of Set 9 | morozovsk
# Processing Record 45 of Set 9 | mehamn
# Processing Record 46 of Set 9 | wasilla
# Processing Record 47 of Set 9 | vila velha
# Processing Record 48 of Set 9 | ghogha
# Processing Record 49 of Set 9 | arequipa
# Processing Record 50 of Set 9 | bousse
# Processing Record 1 of Set 10 | smithers
# Processing Record 2 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 3 of Set 10 | joshimath
# Processing Record 4 of Set 10 | rio gallegos
# Processing Record 5 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 6 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 7 of Set 10 | valenca do piaui
# Processing Record 8 of Set 10 | fortuna
# Processing Record 9 of Set 10 | rio tercero
# Processing Record 10 of Set 10 | hamilton
# Processing Record 11 of Set 10 | kloulklubed
# Processing Record 12 of Set 10 | katherine
# Processing Record 13 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 14 of Set 10 | tecoanapa
# Processing Record 15 of Set 10 | alto baudo
# City not found. Skipping...
# Processing Record 16 of Set 10 | concordia
# Processing Record 17 of Set 10 | sao filipe
# Processing Record 18 of Set 10 | celestun
# Processing Record 19 of Set 10 | flin flon
# Processing Record 20 of Set 10 | safety harbor
# Processing Record 21 of Set 10 | zhanakorgan
# Processing Record 22 of Set 10 | luocheng
# Processing Record 23 of Set 10 | tautira
# Processing Record 24 of Set 10 | goma
# Processing Record 25 of Set 10 | port blair
# Processing Record 26 of Set 10 | kroya
# Processing Record 27 of Set 10 | mahibadhoo
# Processing Record 28 of Set 10 | isangel
# Processing Record 29 of Set 10 | libertador general san martin
# Processing Record 30 of Set 10 | mandalgovi
# Processing Record 31 of Set 10 | nelson bay
# Processing Record 32 of Set 10 | san nicolas
# Processing Record 33 of Set 10 | srednekolymsk
# Processing Record 34 of Set 10 | campoverde
# Processing Record 35 of Set 10 | takaka
# Processing Record 36 of Set 10 | kalianget
# Processing Record 37 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 38 of Set 10 | honiara
# Processing Record 39 of Set 10 | tokonou
# Processing Record 40 of Set 10 | cayenne
# Processing Record 41 of Set 10 | pitimbu
# Processing Record 42 of Set 10 | camopi
# Processing Record 43 of Set 10 | yaan
# Processing Record 44 of Set 10 | sao felix do xingu
# Processing Record 45 of Set 10 | zheleznodorozhnyy
# Processing Record 46 of Set 10 | anloga
# Processing Record 47 of Set 10 | gorontalo
# Processing Record 48 of Set 10 | boguchany
# Processing Record 49 of Set 10 | clonakilty
# Processing Record 50 of Set 10 | guerrero negro
# Processing Record 1 of Set 11 | fort morgan
# Processing Record 2 of Set 11 | palmas de monte alto
# Processing Record 3 of Set 11 | berlevag
# Processing Record 4 of Set 11 | wampusirpi
# City not found. Skipping...
# Processing Record 5 of Set 11 | jamame
# Processing Record 6 of Set 11 | sarkand
# Processing Record 7 of Set 11 | sembe
# Processing Record 8 of Set 11 | ziro
# Processing Record 9 of Set 11 | seydi
# Processing Record 10 of Set 11 | mount gambier
# Processing Record 11 of Set 11 | kupang
# Processing Record 12 of Set 11 | nouakchott
# Processing Record 13 of Set 11 | penzance
# Processing Record 14 of Set 11 | dunedin
# Processing Record 15 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 16 of Set 11 | kirando
# Processing Record 17 of Set 11 | armidale
# Processing Record 18 of Set 11 | wanning
# Processing Record 19 of Set 11 | tahoua
# Processing Record 20 of Set 11 | west wendover
# Processing Record 21 of Set 11 | codrington
# Processing Record 22 of Set 11 | erenhot
# Processing Record 23 of Set 11 | durant
# Processing Record 24 of Set 11 | buchanan
# Processing Record 25 of Set 11 | rundu
# Processing Record 26 of Set 11 | lincoln
# Processing Record 27 of Set 11 | ambilobe
# Processing Record 28 of Set 11 | las palmas
# Processing Record 29 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 30 of Set 11 | mezen
# Processing Record 31 of Set 11 | opuwo
# Processing Record 32 of Set 11 | usinsk
# Processing Record 33 of Set 11 | tarauaca
# Processing Record 34 of Set 11 | kesennuma
# City not found. Skipping...
# Processing Record 35 of Set 11 | dzaoudzi
# Processing Record 36 of Set 11 | necochea
# Processing Record 37 of Set 11 | sao miguel do araguaia
# Processing Record 38 of Set 11 | langarud
# Processing Record 39 of Set 11 | belmonte
# Processing Record 40 of Set 11 | matara
# Processing Record 41 of Set 11 | plettenberg bay
# Processing Record 42 of Set 11 | dukat
# Processing Record 43 of Set 11 | linares
# Processing Record 44 of Set 11 | yanliang
# Processing Record 45 of Set 11 | zhezkazgan
# Processing Record 46 of Set 11 | banikoara
# Processing Record 47 of Set 11 | velika kladusa
# Processing Record 48 of Set 11 | vanavara
# Processing Record 49 of Set 11 | alugan
# Processing Record 50 of Set 11 | sikonge
# Processing Record 1 of Set 12 | bundaberg
# Processing Record 2 of Set 12 | lata
# Processing Record 3 of Set 12 | tonj
# Processing Record 4 of Set 12 | aykhal
# Processing Record 5 of Set 12 | tarko-sale
# Processing Record 6 of Set 12 | nokaneng
# Processing Record 7 of Set 12 | basco
# Processing Record 8 of Set 12 | burkhala
# City not found. Skipping...
# Processing Record 9 of Set 12 | koppang
# Processing Record 10 of Set 12 | kharp
# Processing Record 11 of Set 12 | guatire
# Processing Record 12 of Set 12 | prince george
# Processing Record 13 of Set 12 | ardmore
# Processing Record 14 of Set 12 | salto
# Processing Record 15 of Set 12 | emerald
# Processing Record 16 of Set 12 | aklavik
# Processing Record 17 of Set 12 | bengkulu
# Processing Record 18 of Set 12 | chapais
# Processing Record 19 of Set 12 | moron
# Processing Record 20 of Set 12 | puri
# Processing Record 21 of Set 12 | lodwar
# Processing Record 22 of Set 12 | oktyabrskoye
# Processing Record 23 of Set 12 | megion
# Processing Record 24 of Set 12 | locri
# Processing Record 25 of Set 12 | sumbe
# Processing Record 26 of Set 12 | armacao dos buzios
# City not found. Skipping...
# Processing Record 27 of Set 12 | oranjemund
# Processing Record 28 of Set 12 | luanda
# Processing Record 29 of Set 12 | laguna
# Processing Record 30 of Set 12 | pangody
# Processing Record 31 of Set 12 | nuuk
# Processing Record 32 of Set 12 | kwinana
# Processing Record 33 of Set 12 | vestmanna
# Processing Record 34 of Set 12 | lasa
# Processing Record 35 of Set 12 | chilliwack
# Processing Record 36 of Set 12 | superior
# Processing Record 37 of Set 12 | sao gabriel da cachoeira
# Processing Record 38 of Set 12 | jaciara
# Processing Record 39 of Set 12 | drovyanaya
# Processing Record 40 of Set 12 | ponnani
# Processing Record 41 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 42 of Set 12 | yabrud
# Processing Record 43 of Set 12 | asayita
# City not found. Skipping...
# Processing Record 44 of Set 12 | ngunguru
# Processing Record 45 of Set 12 | umm kaddadah
# Processing Record 46 of Set 12 | pisco
# Processing Record 47 of Set 12 | ostersund
# Processing Record 48 of Set 12 | antofagasta
# Processing Record 49 of Set 12 | manzil tamim
# City not found. Skipping...
# Processing Record 50 of Set 12 | gaborone
# Processing Record 1 of Set 13 | ugoofaaru
# Processing Record 2 of Set 13 | gravdal
# Processing Record 3 of Set 13 | port hedland
# Processing Record 4 of Set 13 | palimbang
# Processing Record 5 of Set 13 | nemuro
# Processing Record 6 of Set 13 | jesup
# Processing Record 7 of Set 13 | wawa
# Processing Record 8 of Set 13 | prince rupert
# Processing Record 9 of Set 13 | urusha
# Processing Record 10 of Set 13 | naze
# Processing Record 11 of Set 13 | zarubino
# Processing Record 12 of Set 13 | buin
# Processing Record 13 of Set 13 | zharkent
# Processing Record 14 of Set 13 | santa cruz
# Processing Record 15 of Set 13 | inirida
# Processing Record 16 of Set 13 | eureka
# Processing Record 17 of Set 13 | champasak
# Processing Record 18 of Set 13 | killybegs
# Processing Record 19 of Set 13 | catuday
# Processing Record 20 of Set 13 | kapit
# Processing Record 21 of Set 13 | bam
# Processing Record 22 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 23 of Set 13 | tokmak
# Processing Record 24 of Set 13 | liwale
# Processing Record 25 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 13 | the valley
# Processing Record 27 of Set 13 | college
# Processing Record 28 of Set 13 | bandarbeyla
# Processing Record 29 of Set 13 | fare
# Processing Record 30 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 31 of Set 13 | nueva loja
# Processing Record 32 of Set 13 | santiago del estero
# Processing Record 33 of Set 13 | dubbo
# Processing Record 34 of Set 13 | khandyga
# Processing Record 35 of Set 13 | muravlenko
# Processing Record 36 of Set 13 | asau
# Processing Record 37 of Set 13 | camacha
# Processing Record 38 of Set 13 | hit
# Processing Record 39 of Set 13 | san lorenzo
# Processing Record 40 of Set 13 | shkotovo-22
# City not found. Skipping...
# Processing Record 41 of Set 13 | christchurch
# Processing Record 42 of Set 13 | tukrah
# Processing Record 43 of Set 13 | tura
# Processing Record 44 of Set 13 | port lincoln
# Processing Record 45 of Set 13 | bukama
# Processing Record 46 of Set 13 | alibag
# Processing Record 47 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 48 of Set 13 | ponta delgada
# Processing Record 49 of Set 13 | geresk
# City not found. Skipping...
# Processing Record 50 of Set 13 | tynda
# Processing Record 1 of Set 14 | bassano
# Processing Record 2 of Set 14 | japura
# Processing Record 3 of Set 14 | palana
# Processing Record 4 of Set 14 | thinadhoo
# Processing Record 5 of Set 14 | pedernales
# Processing Record 6 of Set 14 | rudbar
# Processing Record 7 of Set 14 | sussex
# Processing Record 8 of Set 14 | san miguel
# Processing Record 9 of Set 14 | pakhtakoron
# Processing Record 10 of Set 14 | calbuco
# Processing Record 11 of Set 14 | koksovyy
# Processing Record 12 of Set 14 | comodoro rivadavia
# Processing Record 13 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 14 of Set 14 | buon me thuot
# City not found. Skipping...
# Processing Record 15 of Set 14 | jiaozuo
# Processing Record 16 of Set 14 | sobolevo
# Processing Record 17 of Set 14 | grand-lahou
# Processing Record 18 of Set 14 | kushmurun
# Processing Record 19 of Set 14 | atmakur
# Processing Record 20 of Set 14 | pomabamba
# Processing Record 21 of Set 14 | yeppoon
# Processing Record 22 of Set 14 | garissa
# Processing Record 23 of Set 14 | marawi
# Processing Record 24 of Set 14 | flinders
# Processing Record 25 of Set 14 | sonkovo
# Processing Record 26 of Set 14 | sola
# Processing Record 27 of Set 14 | nandi hills
# Processing Record 28 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 29 of Set 14 | anqiu
# Processing Record 30 of Set 14 | kentau
# Processing Record 31 of Set 14 | hervey bay
# Processing Record 32 of Set 14 | ryazanovskiy
# Processing Record 33 of Set 14 | karpogory
# Processing Record 34 of Set 14 | winnemucca
# Processing Record 35 of Set 14 | peru
# Processing Record 36 of Set 14 | sumbawa
# City not found. Skipping...
# Processing Record 37 of Set 14 | pacifica
# Processing Record 38 of Set 14 | samara
# Processing Record 39 of Set 14 | san rafael
# Processing Record 40 of Set 14 | lere
# Processing Record 41 of Set 14 | dicabisagan
# Processing Record 42 of Set 14 | floriano
# Processing Record 43 of Set 14 | mudyuga
# City not found. Skipping...
# Processing Record 44 of Set 14 | huarmey
# Processing Record 45 of Set 14 | miandrivazo
# Processing Record 46 of Set 14 | pontianak
# Processing Record 47 of Set 14 | pilot butte
# Processing Record 48 of Set 14 | mangrol
# Processing Record 49 of Set 14 | solnechnyy
# Processing Record 50 of Set 14 | gat
# Processing Record 1 of Set 15 | rochegda
# Processing Record 2 of Set 15 | outjo
# Processing Record 3 of Set 15 | rakiv lis
# Processing Record 4 of Set 15 | isla vista
# Processing Record 5 of Set 15 | dingle
# Processing Record 6 of Set 15 | barcelos
# Processing Record 7 of Set 15 | lehi
# Processing Record 8 of Set 15 | purwodadi
# Processing Record 9 of Set 15 | saint-pierre
# Processing Record 10 of Set 15 | katima mulilo
# Processing Record 11 of Set 15 | nizwa
# Processing Record 12 of Set 15 | muskegon
# Processing Record 13 of Set 15 | sweetwater
# Processing Record 14 of Set 15 | carauari
# Processing Record 15 of Set 15 | nueva concepcion
# Processing Record 16 of Set 15 | sungaipenuh
# Processing Record 17 of Set 15 | high level
# Processing Record 18 of Set 15 | kiruna
# Processing Record 19 of Set 15 | burica
# City not found. Skipping...
# Processing Record 20 of Set 15 | maroantsetra
# Processing Record 21 of Set 15 | rio grande
# Processing Record 22 of Set 15 | nishihara
# Processing Record 23 of Set 15 | kribi
# Processing Record 24 of Set 15 | trelew
# Processing Record 25 of Set 15 | boralday
# Processing Record 26 of Set 15 | mkushi
# Processing Record 27 of Set 15 | nangomba
# Processing Record 28 of Set 15 | shelburne
# Processing Record 29 of Set 15 | sinnamary
# Processing Record 30 of Set 15 | wahiawa
# Processing Record 31 of Set 15 | cardonal
# Processing Record 32 of Set 15 | blaubeuren
# Processing Record 33 of Set 15 | imeni poliny osipenko
# Processing Record 34 of Set 15 | guozhen
# Processing Record 35 of Set 15 | westport
# Processing Record 36 of Set 15 | kitimat
# Processing Record 37 of Set 15 | mattru
# Processing Record 38 of Set 15 | saint-augustin
# Processing Record 39 of Set 15 | atbasar
# Processing Record 40 of Set 15 | sefophe
# Processing Record 41 of Set 15 | kaman
# Processing Record 42 of Set 15 | akdepe
# Processing Record 43 of Set 15 | blanquefort
# Processing Record 44 of Set 15 | krasne
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Auki      SB  -8.7676  160.7034     79.18        89          99
# 1      Havelock      US  34.8791  -76.9013     53.56        78         100
# 2  Puerto Ayora      EC  -0.7393  -90.3518     78.76        78          77
# 3    Port Hardy      CA  50.6996 -127.4199     41.76        87          75
# 4       Mataura      NZ -46.1927  168.8643     52.48        90          95
# 5         Bluff      NZ -46.6000  168.3333     52.81        85         100
# 6    Chokurdakh      RU  70.6333  147.9167    -33.00       100         100
# 7         Vaini      TO -21.2000 -175.2000     86.16        74          20
# 8        Yulara      AU -25.2406  130.9889     82.24        54          96
# 9      Balgazyn      RU  51.0000   95.2000    -12.05        97         100
#
#    Wind Speed Current Description
# 0        6.80     overcast clouds
# 1        3.44     overcast clouds
# 2        9.01       broken clouds
# 3        4.61       broken clouds
# 4        5.12     overcast clouds
# 5       11.34     overcast clouds
# 6        6.78     overcast clouds
# 7        9.22          few clouds
# 8        6.91     overcast clouds
# 9        1.39     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
